# %% [markdown]
# <a href="https://colab.research.google.com/github/visheshtechie/DL/blob/master/Lab11_Darknet_Yolo_J018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # The darknet.zip file hosted on google drive contains all the necessary modified files and the gun dataset

# %%
import shutil

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !unzip "/content/drive/My Drive/Sharing_storage1/darknet.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: __MACOSX/darknet/data/labels/._armas (1691).txt
#   inflating: darknet/data/labels/armas (493).txt
#   inflating: __MACOSX/darknet/data/labels/._armas (493).txt
#   inflating: darknet/data/labels/armas (539).txt
#   inflating: __MACOSX/darknet/data/labels/._armas (539).txt
#   inflating: darknet/data/labels/armas (2814).txt
#   inflating: __MACOSX/darknet/data/labels/._armas (2814).txt
#   inflating: darknet/data/labels/armas (2547).txt
#   inflating: __MACOSX/darknet/data/labels/._armas (2547).txt
#   inflating: darknet/data/labels/armas (2117).txt
#   inflating: __MACOSX/darknet/data/labels/._armas (2117).txt
#   inflating: darknet/data/labels/armas (1916).txt
#   inflating: __MACOSX/darknet/data/labels/._armas (1916).txt
#   inflating: darknet/data/labels/armas (2639).txt
#   inflating: __MACOSX/darknet/data/labels/._armas (2639).txt
#   inflating: darknet/data/labels/armas (2269).txt
# ...

# %%
# %cd /content/darknet 
# !make
# !chmod +x ./darknet
# Out:
# /content/darknet
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda/include/cuda_runtime_api.h:957:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
# !rm /content/darknet/backup -r
# !ln -s /content/drive/'My Drive'/YOLOv3_weight/backup /content/darknet

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 25 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 2s (159 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# ...

# %%
# !dos2unix ./data/train.txt
# !dos2unix ./data/val.txt
# !dos2unix ./data/yolo.data
# !dos2unix ./data/yolo.names
# !dos2unix ./cfg/yolov3_custom_train.cfg
# Out:
# dos2unix: converting file ./data/train.txt to Unix format...
# dos2unix: converting file ./data/val.txt to Unix format...
# dos2unix: converting file ./data/yolo.data to Unix format...
# dos2unix: converting file ./data/yolo.names to Unix format...
# dos2unix: converting file ./cfg/yolov3_custom_train.cfg to Unix format...

# %%
# %cd /content/darknet
# !./darknet detector train data/yolo.data cfg/yolov3_custom_train.cfg darknet53.conv.74
# Out:
# Streaming output truncated to the last 5000 lines.
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.491658, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.412072, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.354401, Class: 0.354909, Obj: 0.315315, No Obj: 0.546917, .5R: 0.500000, .75R: 0.000000,  count: 2
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.492765, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.412424, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.150357, Class: 0.902237, Obj: 0.379630, No Obj: 0.546524, .5R: 0.000000, .75R: 0.000000,  count: 1
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.493277, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.025552, Class: 0.638499, Obj: 0.954467, No Obj: 0.410794, .5R: 0.000000, .75R: 0.000000,  count: 1
# ...
